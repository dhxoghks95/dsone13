# %% [markdown]
# # Packages

# %%
from plotnine import *
# %matplotlib inline
import matplotlib.cm as cm
import matplotlib
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
font_location = '/usr/share/fonts/truetype/nanum/NanumGothic.ttf'
font_name = matplotlib.font_manager.FontProperties(fname=font_location).get_name()
matplotlib.rc('font', family=font_name)

# %%
import pandas as pd
import os

# %%
pd.set_option('display.max.columns', None)

# %% [markdown]
# # DATA

# %%
os.chdir('/home/lds/DSL/Github/dsone13/data')

# %%
DT = pd.read_csv('Cine21_Watcha_Daum.csv')

# %%
DT.columns
# Out:
# Index(['씨네21영화코드', '씨네21_제목', '씨네21_연도', '씨네21_국가', '씨네21_등급', '씨네21_장르',
#        '씨네21_상영시간', '씨네21_개봉일', '씨네21_누적관객', '씨네21_감독', '씨네21_출연자',
#        '씨네21_네티즌별점', '씨네21_전문가별점', '씨네21_네티즌수', '씨네21_전문가수', '왓챠_제목', '왓챠_별점',
#        '왓챠_사람', '왓챠_상영시간', '씨네21_제목원문', '왓챠_연도', '왓챠_국가', '왓챠_장르', '씨네21_제목합',
#        '왓챠_제목합', '씨네21_자모', '왓챠_자모', '씨왓_dist', '다음영화코드', '제목_다음', '영어제목_다음',
#        '개봉일_다음', '다음_연도', '국가_다음', '장르_다음', '별점_다음', '네티즌수_다음'],
#       dtype='object')

# %%
DT = DT.loc[DT.씨네21영화코드.drop_duplicates(keep='first').index, :].reset_index(drop=True)',

# %%
DT.columns
# Out:
# Index(['씨네21영화코드', '씨네21_제목', '씨네21_연도', '씨네21_국가', '씨네21_등급', '씨네21_장르',
#        '씨네21_상영시간', '씨네21_개봉일', '씨네21_누적관객', '씨네21_감독', '씨네21_출연자',
#        '씨네21_네티즌별점', '씨네21_전문가별점', '씨네21_네티즌수', '씨네21_전문가수', '왓챠_제목', '왓챠_별점',
#        '왓챠_사람', '왓챠_상영시간', '씨네21_제목원문', '왓챠_연도', '왓챠_국가', '왓챠_장르', '씨네21_제목합',
#        '왓챠_제목합', '씨네21_자모', '왓챠_자모', '씨왓_dist', '다음영화코드', '제목_다음', '영어제목_다음',
#        '개봉일_다음', '다음_연도', '국가_다음', '장르_다음', '별점_다음', '네티즌수_다음'],
#       dtype='object')

# %%
DT = DT[['씨네21영화코드', 
         '씨네21_제목', '씨네21_제목원문', 
         '씨네21_연도', '왓챠_연도',
         '씨네21_국가', '왓챠_국가', 
         '씨네21_등급', 
         '씨네21_장르','왓챠_장르', 
         '씨네21_상영시간', '왓챠_상영시간', 
         '씨네21_개봉일', '개봉일_다음', 
         '씨네21_누적관객', 
         '씨네21_감독', 
         '씨네21_출연자', 
         '다음_연도', 
         '국가_다음', 
         '장르_다음', 
         '왓챠_별점','왓챠_사람', 
         '씨네21_네티즌별점', '씨네21_네티즌수', 
         '씨네21_전문가별점', '씨네21_전문가수', 
         '별점_다음', '네티즌수_다음'
         ]]

# %%
DT[['씨네21_제목', '씨네21_연도', '씨네21_국가', '씨네21_등급', '씨네21_장르',
       '씨네21_상영시간', '씨네21_개봉일', '씨네21_누적관객', '씨네21_감독', '씨네21_출연자',
       '씨네21_네티즌별점', '씨네21_전문가별점', '씨네21_네티즌수', '씨네21_전문가수', '왓챠_제목', '왓챠_별점',
       '왓챠_사람', '왓챠_상영시간', '씨네21_제목원문', '왓챠_국가', '왓챠_장르', ,
       '국가_다음', '장르_다음', '별점_다음', '네티즌수_다음']]
# Out:
#           씨네21_제목  씨네21_연도 씨네21_국가   씨네21_등급           씨네21_장르 씨네21_상영시간  \
# 0              히트   1995.0      미국  청소년 관람불가       액션, 범죄, 드라마      171분
# 1              랜섬   1996.0      미국   15세 관람가       드라마, 범죄, 액션      129분
# 2          귀여운 여인   1990.0      미국  청소년 관람불가       멜로·로맨스, 코미디      125분
# 3      라스베가스를 떠나며   1995.0      미국  청소년 관람불가       드라마, 멜로·로맨스      112분
# 4            보디가드   1992.0      미국   15세 관람가        뮤직, 멜로·로맨스      125분
# ...           ...      ...     ...       ...               ...       ...
# 28616          엑스   2014.0      미국   15세 관람가  코미디, 스릴러, 멜로·로맨스       89분
# 28617    인생은 아름다워   2019.0      한국       NaN               뮤지컬       NaN
# 28618    교실 안의 야크   2019.0      부탄    전체 관람가               드라마      109분
# 28619      3년째의데뷔   2020.0      일본       NaN             다큐멘터리      119분
# 28620      아메리칸 잡   2019.0      미국   15세 관람가            액션, 범죄       NaN
#
#          씨네21_개봉일 씨네21_누적관객     씨네21_감독                 씨네21_출연자  씨네21_네티즌별점  \
# 0      2017-11-09      454명       마이클 만     ['알 파치노', '로버트 드니로']        8.44
# 1      1996-12-07       NaN       론 하워드        ['멜 깁슨', '르네 루소']        6.29
# 2      1990-09-15       NaN       게리 마샬    ['리처드 기어', '줄리아 로버츠']        7.37
# 3      1996-03-01       84명     마이크 피기스  ['니콜라스 케이지', '엘리자베스 슈']        7.97
# 4      2018-09-26       NaN        믹 잭슨   ['케빈 코스트너', '휘트니 휴스턴']        6.36
# ...           ...       ...         ...                      ...         ...
# 28616         NaN       NaN        조 단테  ['안톤 옐친', '알렉산드라 다다리오']         NaN
# 28617      20-Dec       NaN         최국희           ['류승룡', '염정아']         NaN
# 28618  2020-09-30    3,425명  파우 초이닝 도르지        ['셰랍 도르지', '펨 잠']         NaN
# 28619         NaN       NaN    타케나카 유스케                       []         NaN
# 28620  2020-09-03    2,156명   마크 스티븐 존슨  ['트래비스 핌멜', '포레스트 휘태커']         NaN
#
#        씨네21_전문가별점  씨네21_네티즌수  씨네21_전문가수       왓챠_제목  왓챠_별점 왓챠_사람  왓챠_상영시간  \
# 0             NaN       40.0        0.0          히트    3.9    5만  2시간 51분
# 1             NaN       21.0        0.0          랜섬    3.4    2만   2시간 1분
# 2             NaN       39.0        0.0      귀여운 여인    3.8   24만  1시간 59분
# 3             NaN       37.0        0.0  라스베가스를 떠나며    3.7    3만  1시간 51분
# 4             NaN       25.0        0.0        보디가드    3.6    9만      NaN
# ...           ...        ...        ...         ...    ...   ...      ...
# 28616         NaN        0.0        0.0          엑스    2.5     3  1시간 44분
# 28617         NaN        0.0        0.0    인생은 아름다워    3.5    11      NaN
# 28618         7.0        0.0        2.0    교실 안의 야크    3.8   347  1시간 50분
# 28619         NaN        0.0        0.0     3년째의 데뷔    3.5     1  1시간 59분
# 28620         6.5        0.0        2.0      아메리칸 잡    2.6   144      NaN
#
#                             씨네21_제목원문   왓챠_연도   왓챠_국가       왓챠_장르      제목_다음  \
# 0                                Heat  1995.0  ['미국']      ['액션']         히트
# 1                              Ransom  1996.0  ['미국']      ['범죄']         랜섬
# 2                        Pretty Woman  1990.0  ['미국']  ['로맨틱코미디']      귀여운여인
# 3                   Leaving Las Vegas  1995.0  ['미국']     ['로맨스']  라스베가스를떠나며
# 4                       The Bodyguard  1992.0  ['미국']      ['액션']       보디가드
# ...                               ...     ...     ...         ...        ...
# 28616                  Burying the Ex  1983.0  ['한국']          []         엑스
# 28617                             NaN  2019.0  ['한국']      ['음악']    인생은아름다워
# 28618  Lunana: A Yak in the Classroom  2019.0  ['부탄']     ['드라마']     교실안의야크
# 28619                        3年目のデビュー  2020.0  ['일본']   ['다큐멘터리']     3년째의데뷔
# 28620           Finding Steve McQueen  2019.0  ['미국']     ['로맨스']      아메리칸잡
#
#                                                  영어제목_다음        국가_다음  \
# 0                                                   heat           미국
# 1                                                 ransom           미국
# 2                                            prettywoman           미국
# 3                                        leavinglasvegas  프랑스, 영국, 미국
# 4                                           thebodyguard           미국
# ...                                                  ...          ...
# 28616                                       buryingtheex           미국
# 28617                                                NaN           한국
# 28618                          lunana:ayakintheclassroom           부탄
# 28619  hinatazaka46documentarymovie:debutafter3years,...           일본
# 28620                                findingstevemcqueen           미국
#
#                장르_다음  별점_다음  네티즌수_다음
# 0              범죄/액션    9.0      196
# 1             범죄/스릴러    7.9       43
# 2         코미디/로맨스/멜로    8.6      175
# 3         로맨스/멜로/드라마    8.6       98
# 4             로맨스/멜로    8.6      117
# ...              ...    ...      ...
# 28616  공포/로맨스/멜로/코미디    5.7       21
# 28617            뮤지컬    9.6       24
# 28618            드라마    9.1       27
# 28619          다큐멘터리    0.0        0
# 28620          범죄/액션    6.1       12
#
# [28621 rows x 28 columns]

# %%
DT.씨네21_등급.value_counts()
# Out:
# 15세 관람가     5781
# 청소년 관람불가    4693
# 12세 관람가     2847
# 전체 관람가      1987
# 제한 상영가        17
# 7세 관람가         2
# Name: 씨네21_등급, dtype: int64
