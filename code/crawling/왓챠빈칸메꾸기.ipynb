# %%
import pandas as pd
from tqdm import tqdm, tqdm_notebook
import requests
from bs4 import BeautifulSoup
import time
import random

# %%
import os
os.chdir('C:\\Users\\reoeu\\Desktop\\2020-2\\데이터사이언스\\project\\데이터')
T = pd.read_csv('Cine21(完).csv')
W = pd.read_csv('왓챠.csv')

# %%
HM = pd.read_csv('tohowmany.csv').drop(['Unnamed: 0'], axis=1)

# %%
HM
# Out:
#        Unnamed: 0.1              제목_x      연도   국가        등급           장르  \
# 0                 1                히트  1995.0   미국  청소년 관람불가  액션, 범죄, 드라마
# 1                 2                랜섬  1996.0   미국   15세 관람가  드라마, 범죄, 액션
# 2                 3            귀여운 여인  1990.0   미국  청소년 관람불가  멜로·로맨스, 코미디
# 3                 4        라스베가스를 떠나며  1995.0   미국  청소년 관람불가  드라마, 멜로·로맨스
# 4                 5              보디가드  1992.0   미국   15세 관람가   뮤직, 멜로·로맨스
# ...             ...               ...     ...  ...       ...          ...
# 52043         56746            3년째의데뷔  2020.0   일본       NaN        다큐멘터리
# 52044         56747            이별의 목적  2018.0  NaN   12세 관람가       멜로·로맨스
# 52045         56748       압구정 리포트(가제)     NaN   한국       NaN          NaN
# 52046         56749            아메리칸 잡  2019.0   미국   15세 관람가       액션, 범죄
# 52047         56750  조제, 호랑이 그리고 물고기들     NaN   일본       NaN   애니메이션, 드라마
#
#       상영시간_x         개봉일    누적관객         감독                      출연자   네티즌  \
# 0       171분  2017-11-09    454명      마이클 만     ['알 파치노', '로버트 드니로']  8.44
# 1       129분  1996-12-07     NaN      론 하워드        ['멜 깁슨', '르네 루소']  6.29
# 2       125분  1990-09-15     NaN      게리 마샬    ['리처드 기어', '줄리아 로버츠']  7.37
# 3       112분  1996-03-01     84명    마이크 피기스  ['니콜라스 케이지', '엘리자베스 슈']  7.97
# 4       125분  2018-09-26     NaN       믹 잭슨   ['케빈 코스트너', '휘트니 휴스턴']  6.36
# ...      ...         ...     ...        ...                      ...   ...
# 52043   119분         NaN     NaN   타케나카 유스케                       []   NaN
# 52044    96분      20-Sep    214명        이건우                  ['한해인']   NaN
# 52045    NaN         NaN     NaN        임진순           ['마동석', '정경호']   NaN
# 52046    NaN  2020-09-03  2,156명  마크 스티븐 존슨  ['트래비스 핌멜', '포레스트 휘태커']   NaN
# 52047    NaN      21-Jan     NaN    타무라 코타로                       []   NaN
#
#        전문가  네티즌수  전문가수              제목_y   별점   사람                    기타정보  \
# 0      NaN    40   0.0                히트  3.9   5만      ['1995 ・ 액션 ・ 미국']
# 1      NaN    21   0.0                랜섬  3.4   2만      ['1996 ・ 범죄 ・ 미국']
# 2      NaN    39   0.0            귀여운 여인  3.8  24만  ['1990 ・ 로맨틱코미디 ・ 미국']
# 3      NaN    37   0.0        라스베가스를 떠나며  3.7   3만     ['1995 ・ 로맨스 ・ 미국']
# 4      NaN    25   0.0              보디가드  3.6   9만      ['1992 ・ 액션 ・ 미국']
# ...    ...   ...   ...               ...  ...  ...                     ...
# 52043  NaN     0   0.0           3년째의 데뷔  3.5    1   ['2020 ・ 다큐멘터리 ・ 일본']
# 52044  5.0     0   1.0            이별의 목적  2.7   68     ['2018 ・ 드라마 ・ 한국']
# 52045  NaN     0   0.0       압구정 리포트(가제)  0.0    0     ['2020 ・ 코미디 ・ 한국']
# 52046  6.5     0   2.0            아메리칸 잡  2.6  144     ['2019 ・ 로맨스 ・ 미국']
# 52047  NaN     0   0.0  조제, 호랑이 그리고 물고기들  NaN  NaN     [2020 · 일본 · 애니메이션]
#
#         상영시간_y
# 0      2시간 51분
# 1       2시간 1분
# 2      1시간 59분
# 3      1시간 51분
# 4          NaN
# ...        ...
# 52043  1시간 59분
# 52044      NaN
# 52045      NaN
# 52046      NaN
# 52047  1시간 39분
#
# [52048 rows x 20 columns]

# %%
tobesearched = list(HM[(HM.제목_y == '') | (HM.제목_y.isnull()) ]['Unnamed: 0.1'])

# %%
session = requests.Session()
headers = {
    "User-Agent": "Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_5) AppleWebKit 537.36 (KHTML, like Gecko) Chrome",
    "Accept": "text/html,application/xhtml+xml,application/xml;q=0.9,image/webp,*/*;q=0.8"
}

# %%
    URL = 'http://www.cine21.com/movie/info/?movie_id={}'.format(11)
    html = session.get(URL, headers=headers).text
    soup = BeautifulSoup(html, 'html.parser')

# %%
soup.select('#container > div.movie_detail_top_area > div > div > div.mov_info > p.tit_eng > span')[0].text
# Out:
# 'Michael Collins'

# %%
full = {}
for i in tqdm_notebook(tobesearched):
    
    URL = 'http://www.cine21.com/movie/info/?movie_id={}'.format(i)
    html = session.get(URL, headers=headers).text
    soup = BeautifulSoup(html, 'html.parser')


    try:
        제목 = soup.select('#container > div.movie_detail_top_area > div > div > div.mov_info > p.tit_eng > span')[0].text
    except:
        제목 = ""
    
    single = {'제목원문':제목}
    
    full[i] = single
    
    rand_value = random.uniform(0, 1)
    time.sleep(rand_value)
# Out:
# C:\Users\reoeu\anaconda3\lib\site-packages\ipykernel_launcher.py:2: TqdmDeprecationWarning: This function will be removed in tqdm==5.0.0
# Please use `tqdm.notebook.tqdm` instead of `tqdm.tqdm_notebook`
# HBox(children=(HTML(value=''), FloatProgress(value=0.0, max=18878.0), HTML(value='')))
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-25-fd931e79816d> in <module>
#      17
#      18     rand_value = random.uniform(0, 1)
# ---> 19     time.sleep(rand_value)
#
# KeyboardInterrupt:
