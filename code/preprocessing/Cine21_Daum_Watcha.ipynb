# %%
import pandas as pd
from tqdm import tqdm, tqdm_notebook
import requests
from bs4 import BeautifulSoup
import time
import random

# %%
import os
os.chdir('/home/lds/DSL/Github/dsone13/data')

# %%
W = pd.read_csv('watcha_fin.csv').drop('Unnamed: 0', axis=1)

# %%
D = pd.read_csv('/home/lds/DSL/Github/dsone13/data/daum_cine21_merge.csv')

# %%
MM = pd.merge(W,D, how='right', left_on='Unnamed: 0.1', right_on = '씨네21영화코드')

# %%
MM.columns = ['씨네21번호', '씨네21_제목', '씨네21_연도', '씨네21_국가', '씨네21_등급', '씨네21_장르', '씨네21_상영시간', '씨네21_개봉일', '씨네21_누적관객',
       '씨네21_감독', '씨네21_출연자', '씨네21_네티즌별점', '씨네21_전문가별점', '씨네21_네티즌수', '씨네21_전문가수', '왓챠_제목', '왓챠_별점', '왓챠_사람', '왓챠_상영시간',
       '씨네21_제목원문', '왓챠_연도', '왓챠_국가', '왓챠_장르', '씨네21_제목합', '왓챠_제목합', '씨네21_자모', '왓챠_자모',
       '씨왓_dist', '다음영화코드', '씨네21영화코드', '제목_다음', '영어제목_다음', '개봉일_다음', '다음_연도',
       '국가_다음', '장르_다음', '별점_다음', '네티즌수_다음']

# %%
MM = MM.sort_values('씨네21영화코드').reset_index(drop=True)

# %%
MM = MM[['씨네21영화코드', '씨네21_제목', '씨네21_연도', '씨네21_국가', '씨네21_등급', '씨네21_장르', '씨네21_상영시간', '씨네21_개봉일', '씨네21_누적관객',
       '씨네21_감독', '씨네21_출연자', '씨네21_네티즌별점', '씨네21_전문가별점', '씨네21_네티즌수', '씨네21_전문가수', '왓챠_제목', '왓챠_별점', '왓챠_사람', '왓챠_상영시간',
       '씨네21_제목원문', '왓챠_연도', '왓챠_국가', '왓챠_장르', '씨네21_제목합', '왓챠_제목합', '씨네21_자모', '왓챠_자모',
       '씨왓_dist', '다음영화코드', '제목_다음', '영어제목_다음', '개봉일_다음', '다음_연도',
       '국가_다음', '장르_다음', '별점_다음', '네티즌수_다음']]

# %%
MM
# Out:
#        씨네21영화코드     씨네21_제목  씨네21_연도 씨네21_국가   씨네21_등급           씨네21_장르  \
# 0             1          히트   1995.0      미국  청소년 관람불가       액션, 범죄, 드라마
# 1             2          랜섬   1996.0      미국   15세 관람가       드라마, 범죄, 액션
# 2             3      귀여운 여인   1990.0      미국  청소년 관람불가       멜로·로맨스, 코미디
# 3             4  라스베가스를 떠나며   1995.0      미국  청소년 관람불가       드라마, 멜로·로맨스
# 4             5        보디가드   1992.0      미국   15세 관람가        뮤직, 멜로·로맨스
# ...         ...         ...      ...     ...       ...               ...
# 58408     56738          엑스   2014.0      미국   15세 관람가  코미디, 스릴러, 멜로·로맨스
# 58409     56741    인생은 아름다워   2019.0      한국       NaN               뮤지컬
# 58410     56742    교실 안의 야크   2019.0      부탄    전체 관람가               드라마
# 58411     56746      3년째의데뷔   2020.0      일본       NaN             다큐멘터리
# 58412     56749      아메리칸 잡   2019.0      미국   15세 관람가            액션, 범죄
#
#       씨네21_상영시간    씨네21_개봉일 씨네21_누적관객     씨네21_감독  ... 씨왓_dist  다음영화코드  \
# 0          171분  2017-11-09      454명       마이클 만  ...     1.0   17301
# 1          129분  1996-12-07       NaN       론 하워드  ...     1.0    1807
# 2          125분  1990-09-15       NaN       게리 마샬  ...     1.0    1231
# 3          112분  1996-03-01       84명     마이크 피기스  ...     1.0    1860
# 4          125분  2018-09-26       NaN        믹 잭슨  ...     1.0    1727
# ...         ...         ...       ...         ...  ...     ...     ...
# 58408       89분         NaN       NaN        조 단테  ...     1.0   88140
# 58409       NaN      20-Dec       NaN         최국희  ...     1.0  133709
# 58410      109분  2020-09-30    3,425명  파우 초이닝 도르지  ...     1.0  135074
# 58411      119분         NaN       NaN    타케나카 유스케  ...     1.0  143739
# 58412       NaN  2020-09-03    2,156명   마크 스티븐 존슨  ...     1.0  129489
#
#            제목_다음                                            영어제목_다음  \
# 0             히트                                               heat
# 1             랜섬                                             ransom
# 2          귀여운여인                                        prettywoman
# 3      라스베가스를떠나며                                    leavinglasvegas
# 4           보디가드                                       thebodyguard
# ...          ...                                                ...
# 58408         엑스                                       buryingtheex
# 58409    인생은아름다워                                                NaN
# 58410     교실안의야크                          lunana:ayakintheclassroom
# 58411     3년째의데뷔  hinatazaka46documentarymovie:debutafter3years,...
# 58412      아메리칸잡                                findingstevemcqueen
#
#            개봉일_다음 다음_연도        국가_다음          장르_다음 별점_다음 네티즌수_다음
# 0      2017-11-09  1995           미국          범죄/액션   9.0     196
# 1      1996-12-07  1996           미국         범죄/스릴러   7.9      43
# 2      1990-09-15  1990           미국     코미디/로맨스/멜로   8.6     175
# 3      1996-03-01  1995  프랑스, 영국, 미국     로맨스/멜로/드라마   8.6      98
# 4      2018-09-26  1992           미국         로맨스/멜로   8.6     117
# ...           ...   ...          ...            ...   ...     ...
# 58408  2020-08-13  2014           미국  공포/로맨스/멜로/코미디   5.7      21
# 58409  2020-12-00  2019           한국            뮤지컬   9.6      24
# 58410  2020-09-30  2019           부탄            드라마   9.1      27
# 58411  2020-08-07  2020           일본          다큐멘터리   0.0       0
# 58412  2020-09-03  2019           미국          범죄/액션   6.1      12
#
# [58413 rows x 37 columns]
