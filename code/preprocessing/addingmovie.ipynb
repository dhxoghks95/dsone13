# %% [markdown]
# # 1. Importing Packages

# %%
import pandas as pd
import numpy as np
import re
from datetime import datetime

# %% [markdown]
# ## 2. Naver Movie

# %%
naver = pd.read_csv("https://raw.githubusercontent.com/dhxoghks95/dsone13/master/data/naver_movie.csv")

# %%
naver = naver.drop(columns = ['Unnamed: 0'])

# %%
naver[naver['장르']=='드라마']
# Out:
#                                   제목  네티즌평점  관람객평점  평론가평점  누적관객수         개봉일  \
# 7                  3개의 얼굴들 (3 FACES)   0.00    NaN    NaN    NaN  2020.09.09
# 8                    438일 (438 DAYS)   0.00    NaN    NaN    NaN     2020.09
# 9                  69세 (An Old Lady)   8.63   9.30   6.00  8,825  2020.08.20
# 13                    #살아있다 (#ALIVE)   4.15   7.03   5.57    NaN  2020.06.24
# 26                    걸후드 (Girlhood)    NaN    NaN    NaN    NaN  2020.11.12
# ...                              ...    ...    ...    ...    ...         ...
# 24823           해양법 (Law of the Sea)   0.00    NaN    NaN    NaN  1949.06.03
# 24831  한 발은 천국에 (One Foot in Heaven)   0.00    NaN    NaN    NaN  1948.03.18
# 24833           해양법 (Law of the Sea)   0.00    NaN    NaN    NaN  1949.06.03
# 24841  한 발은 천국에 (One Foot in Heaven)   0.00    NaN    NaN    NaN  1948.03.18
# 24843           해양법 (Law of the Sea)   0.00    NaN    NaN    NaN  1949.06.03
#
#        개봉연도   장르  상영시간   국가          등급        감독                      주연  \
# 7      2020  드라마  100분  프랑스  [국내]15세관람가   자파르 파나히         베나즈 자파리,자파르 파나히
# 8      2020  드라마  124분  스웨덴  [국내]15세관람가  예스퍼 갠스란트     구스타프 스카스가드,마티아스 바레라
# 9      2020  드라마  100분   한국  [국내]15세관람가       임선애             예수정,기주봉,김준경
# 13     2020  드라마   98분   한국  [국내]15세관람가       조일형                 유아인,박신혜
# 26     2020  드라마  112분  프랑스  [국내]12세관람가    셀린 시아마     카리자 투레,아사 실라,마리투 투레
# ...     ...  ...   ...  ...         ...       ...                     ...
# 24823  1931  드라마   64분   미국         NaN    오토 브로워  윌리엄 파넘,월리 앨브라이트,랠프 아인스
# 24831  1941  드라마  108분   미국         NaN     어빙 래퍼          프레드릭 마치,마샤 스코트
# 24833  1931  드라마   64분   미국         NaN    오토 브로워  윌리엄 파넘,월리 앨브라이트,랠프 아인스
# 24841  1941  드라마  108분   미국         NaN     어빙 래퍼          프레드릭 마치,마샤 스코트
# 24843  1931  드라마   64분   미국         NaN    오토 브로워  윌리엄 파넘,월리 앨브라이트,랠프 아인스
#
#        네티즌리뷰수  평론가리뷰수                                                URL  \
# 7         NaN     0.0  https://movie.naver.com/movie/bi/mi/basic.nhn?...
# 8         NaN     NaN  https://movie.naver.com/movie/bi/mi/basic.nhn?...
# 9       7,587     6.0  https://movie.naver.com/movie/bi/mi/basic.nhn?...
# 13     17,899     7.0  https://movie.naver.com/movie/bi/mi/basic.nhn?...
# 26        NaN     0.0  https://movie.naver.com/movie/bi/mi/basic.nhn?...
# ...       ...     ...                                                ...
# 24823     NaN     NaN  https://movie.naver.com/movie/bi/mi/basic.nhn?...
# 24831     NaN     NaN  https://movie.naver.com/movie/bi/mi/basic.nhn?...
# 24833     NaN     NaN  https://movie.naver.com/movie/bi/mi/basic.nhn?...
# 24841     NaN     NaN  https://movie.naver.com/movie/bi/mi/basic.nhn?...
# 24843     NaN     NaN  https://movie.naver.com/movie/bi/mi/basic.nhn?...
#
#          영화코드
# 7      174831
# 8      195072
# 9      189373
# 13     189537
# 26     129860
# ...       ...
# 24823  153289
# 24831  137283
# 24833  153289
# 24841  137283
# 24843  153289
#
# [4204 rows x 17 columns]

# %% [markdown]
# ### a) 영어제목 따로 떼기

# %%
entitles = list()
for i in range(len(naver)):
    entitle = re.findall('\(([^)]+)',naver['제목'][i])
    영화코드 = naver['영화코드'][i]
    if len(entitle) == 0:
        entitles = entitles + [["NaN", 영화코드]]
    else:
        entitle = entitle + [영화코드]
        entitles = entitles + [entitle]

# %%
entitles = pd.DataFrame(entitles)
entitles = entitles.iloc[:,0:2]
entitles.columns = ['entitle', '영화코드']
entitles = entitles.reset_index(drop = True)

# %%
naver_merged = naver.merge(entitles, how = 'left', on = '영화코드')
naver_merged = naver_merged[naver_merged.duplicated(keep = 'first') == False]
naver_merged = naver_merged.reset_index(drop = True)

# %%
for i in range(naver_merged.shape[0]):
    title = re.sub(r'\([^)]*\)', '', naver_merged['제목'][i])
    title = title.strip()
    naver_merged['제목'][i] = title
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.

# %%
naver_merged
# Out:
#                       제목  ...                                   entitle
# 0      108명의 여자와 섹스하는 방법  ...  108: REVENGE AND ADVENTURE OF GORO KAIBA
# 1             16세의 사운드트랙  ...                     Soundtrack to Sixteen
# 2                   1917  ...                                      1917
# 3           1942: 언노운 배틀  ...                            Unknown Battle
# 4      1945: 포인트 오브 노 리턴  ...     The Eastern Front: Point of No Return
# ...                  ...  ...                                       ...
# 24745            홍차기의 일생  ...                                       NaN
# 24746             황야의 결투  ...                     My Darling Clementine
# 24747            회의는 춤춘다  ...                           Congress Dances
# 24748              흙에 산다  ...                                       NaN
# 24749             희망의 마을  ...                                       NaN
#
# [24750 rows x 18 columns]

# %% [markdown]
# ### 2. 짜잘한 전처리

# %%
naver_merged = naver_merged[pd.isnull(naver_merged['네티즌리뷰수'])==False]
naver_merged = naver_merged.drop_duplicates(keep = 'first')
naver_merged = naver_merged[naver_merged['네티즌리뷰수'] != 0]
naver_merged['네티즌평점'][pd.isnull(naver_merged['네티즌평점'])] = 0
naver_merged['entitle'] = naver_merged['entitle'].str.lower()
naver_merged = naver_merged.reset_index(drop = True)
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.

# %%
naver_merged
# Out:
#                       제목  ...                                   entitle
# 0      108명의 여자와 섹스하는 방법  ...  108: revenge and adventure of goro kaiba
# 1             16세의 사운드트랙  ...                     soundtrack to sixteen
# 2                   1917  ...                                      1917
# 3           1942: 언노운 배틀  ...                            unknown battle
# 4      1945: 포인트 오브 노 리턴  ...     the eastern front: point of no return
# ...                  ...  ...                                       ...
# 19562                풍년가  ...                                       nan
# 19563            프라하의 학생  ...                      der student von prag
# 19564            홍차기의 일생  ...                                       nan
# 19565             황야의 결투  ...                     my darling clementine
# 19566              흙에 산다  ...                                       nan
#
# [19567 rows x 18 columns]

# %% [markdown]
# ### 3. 개봉 연도, 월 칼럼 만들기

# %%
def grap_year(data):
    data = str(data)
    if data != "nan":
        return data[:4]
    else:
        return "NaN"

def grap_month(data):
    data = str(data)
    if data != "nan":
        return data[5:7]
    else:
        return "NaN"

# %%
naver_merged['year'] = naver_merged['개봉일'].apply(lambda x: grap_year(x))
naver_merged['month'] = naver_merged['개봉일'].apply(lambda x: grap_month(x))

# %%
naver_merged
# Out:
#                       제목  네티즌평점  ...  year  month
# 0      108명의 여자와 섹스하는 방법   1.00  ...  2020     05
# 1             16세의 사운드트랙   8.00  ...  2020     07
# 2                   1917   8.86  ...  2020     02
# 3           1942: 언노운 배틀   8.01  ...  2020     07
# 4      1945: 포인트 오브 노 리턴   3.64  ...  2020     06
# ...                  ...    ...  ...   ...    ...
# 19562                풍년가  10.00  ...   NaN    NaN
# 19563            프라하의 학생   1.00  ...   NaN    NaN
# 19564            홍차기의 일생  10.00  ...   NaN    NaN
# 19565             황야의 결투   7.50  ...  2010     11
# 19566              흙에 산다  10.00  ...   NaN    NaN
#
# [19567 rows x 20 columns]

# %% [markdown]
# ## 3. Daum Movie

# %%
daum = pd.read_csv("https://raw.githubusercontent.com/dhxoghks95/dsone13/master/data/daum_movie.csv")

# %% [markdown]
# ### a) 개봉연도, 월 칼럼 만들기

# %%
daum['year'] = daum['개봉일'].apply(lambda x: grap_year(x))
daum['month'] = daum['개봉일'].apply(lambda x: grap_month(x))

# %%
daum
# Out:
#           영화코드                          제목  ...  year month
# 0            1                     플란다스의 개  ...  2000    02
# 1            2                          카라  ...  1999    09
# 2            3                    주노명 베이커리  ...  2000    01
# 3            4                여고괴담 두번째 이야기  ...  1999    12
# 4            5                     행복한 장의사  ...  2000    01
# ...        ...                         ...  ...   ...   ...
# 125470  145294                   데빌 인사이드 미  ...  2020    11
# 125471  145295                         보이스  ...   NaN   NaN
# 125472  145296                드라이브: 분노의 질주  ...  2020    11
# 125473  145297            해피 데스데이: 악마의 큐피드  ...  2020    11
# 125474  145298  더 비 지스: 하우 캔 유 멘드 어 브로큰 하트  ...   NaN   NaN
#
# [125475 rows x 10 columns]

# %%
daum = daum[daum['네티즌수'] != 0]

# %% [markdown]
# ## 4. 두 테이블 합치기(key = 제목, year, month)

# %%
merged = pd.merge(daum, naver_merged, how = 'outer', on = ['제목', 'year', 'month'])

# %%
merged = merged.drop_duplicates(keep = 'first')

# %% [markdown]
# ### a) 필요한 칼럼들만 뽑기

# %%
merged = merged[['제목', '영화코드_y', '영화코드_x',  '네티즌평점', '네티즌리뷰수', '별점', '네티즌수', 'year', 'month' ]]

# %% [markdown]
# ### b) Null값은 0으로

# %%
merged = merged[pd.isnull(merged['영화코드_y']) == False]
merged = merged[pd.isnull(merged['영화코드_x']) == False]
merged[pd.isnull(merged['별점'])] = 0
merged[pd.isnull(merged['네티즌수'])] = 0
merged[pd.isnull(merged['네티즌리뷰수'])] = 0
merged[merged['네티즌리뷰수'] == 'nan'] = 0

# %% [markdown]
# ### c) Naver 영화에 1,000과 같이 쉼표가 붙어있는 숫자가 있어서 int형식으로 변환

# %%
import locale
locale.setlocale( locale.LC_ALL, 'en_US.UTF-8' ) 
merged['네티즌리뷰수'] = merged['네티즌리뷰수'].apply(lambda x: str(x))
merged['네티즌리뷰수'] = merged['네티즌리뷰수'].apply(lambda x: int(locale.atoi(x)))
merged['total_reviewer'] = merged['네티즌리뷰수'] + merged['네티즌수']

# %% [markdown]
# ### d) Beta Posterior의 95% 하한선을 정규근사를 통해 구하기

# %%
merged['total_star'] = merged['네티즌평점'] * merged['네티즌리뷰수'] / 10 + merged['별점'] * merged['네티즌수'] / 10

# %%
merged[['제목', '영화코드_x', '영화코드_y', 'total_star', 'total_reviewer']]

merged = merged[merged['제목'] != 0 ]

# %%
merged['a'] = merged['total_star'] + 1
merged['b'] = 1 + merged['total_reviewer'] - merged['total_star']

merged['mu'] = merged['a'] / (merged['a']+merged['b'])

merged['std_err'] = 1.65 * np.sqrt((merged['a'] * merged['b']) / (((merged['a'] + merged['b'])**2) * (merged['a'] + merged['b'] + 1 )) )

merged['lb'] = merged['mu'] - merged['std_err']

# %%
merged_reorder = merged.sort_values('lb', ascending = False)
merged_reorder = merged_reorder.reset_index(drop = True)

# %%
merged_reorder
# Out:
#                 제목  영화코드_y    영화코드_x  ...        mu   std_err        lb
# 0       아픈 만큼 사랑한다  182777  129495.0  ...  0.977806  0.016277  0.961529
# 1           환상의 커플   63048   11106.0  ...  0.970619  0.014073  0.956546
# 2         네 멋대로 해라   37925    2919.0  ...  0.962136  0.010327  0.951809
# 3             그린 북  171539  123948.0  ...  0.955271  0.003857  0.951414
# 4             가버나움  174830  121059.0  ...  0.956230  0.005514  0.950716
# ...            ...     ...       ...  ...       ...       ...       ...
# 11223  캠프 살인사건의 비밀  163032  112386.0  ...  0.275000  0.329484 -0.054484
# 11224     마지막 떡국열차  117277   83662.0  ...  0.275000  0.329484 -0.054484
# 11225     이블데드 본리스  159335  110250.0  ...  0.275000  0.329484 -0.054484
# 11226      음란한 첫경험   86117   66709.0  ...  0.275000  0.329484 -0.054484
# 11227      저스티스 배틀  174370  121289.0  ...  0.220000  0.279040 -0.059040
#
# [11228 rows x 16 columns]

# %%
merged_reorder.to_csv('merged_reorder.csv')

# %%
from google.colab import files
files.download("merged_reorder.csv")
